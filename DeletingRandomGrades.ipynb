# %%
import pandas as pd

# %% [markdown]
# 2019/2020

# %%
df = pd.read_excel('Male 19_20.xlsx')
new_1920 = df.sample(24)

# %% [markdown]
# 2020/2021

# %%
df = pd.read_excel('Male 20_21.xlsx')
new_2021 = df.sample(39)

# %% [markdown]
# 2021/2022

# %%
df = pd.read_excel('Male 21_22.xlsx')
new_2122 = df.sample(18)
